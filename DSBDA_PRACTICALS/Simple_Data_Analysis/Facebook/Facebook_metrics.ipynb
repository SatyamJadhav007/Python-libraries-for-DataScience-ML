# %%
import pandas as pd

# %%
df=pd.read_csv("dataset_facebook.csv",delimiter=';') 
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
subset1=df[['Type','Category','Post Month']]  #Getting the subsets from the main dataset
print(subset1.head())
# Out:
#      Type  Category  Post Month
# 0   Photo         2          12
# 1  Status         2          12
# 2   Photo         3          12
# 3   Photo         2          12
# 4   Photo         2          12

# %%
subset2=df[['comment','Post Weekday','like']] 
print(subset2.head())
# Out:
#    comment  Post Weekday    like
# 0        4             4    79.0
# 1        5             3   130.0
# 2        0             3    66.0
# 3       58             2  1572.0
# 4       19             2   325.0

# %%
# Merging the dataset now as the requirement 2 of the problem statement  
merged=pd.concat([subset1,subset2],axis=1)
print(merged.head())
# Out:
#      Type  Category  Post Month  comment  Post Weekday    like
# 0   Photo         2          12        4             4    79.0
# 1  Status         2          12        5             3   130.0
# 2   Photo         3          12        0             3    66.0
# 3   Photo         2          12       58             2  1572.0
# 4   Photo         2          12       19             2   325.0

# %%
# Sorting the values on the basis of the likes 
sorted_df=df.sort_values(by=['like'],ascending=False) 
sorted_df.head(10)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# 460             92507  Photo         3           2             1         13
# 101            137020  Photo         2          10             4          3
# 323            123047  Photo         3           6             1         10
# 199            132817  Photo         3           8             4         10
# 176            135195  Photo         3           9             6          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
# Transposing the dataset values 
Transposed_dataset=df.head().transpose() 
Transposed_dataset.head()
# Out:
#                        0       1       2       3       4
# Page total likes  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo
# Category               2       2       3       2       2
# Post Month            12      12      12      12      12
# Post Weekday           4       3       3       2       2

# %%
import numpy as np 
# Changing the dataset dimensions(i.e. Reshaping)
arr=np.array(df[['Post Month','Post Weekday']].head(6)) 
reshaped=arr.reshape(3,4) 
reshaped
# Out:
# array([[12,  4, 12,  3],
#        [12,  3, 12,  2],
#        [12,  2, 12,  1]])
