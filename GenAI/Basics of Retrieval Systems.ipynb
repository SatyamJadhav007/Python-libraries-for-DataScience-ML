# %% [markdown]
# # Libraries and Data

# %%
# Sample documents about sailing in Croatia
documents = ['Sailing in Croatia often includes visiting UNESCO World Heritage sites.',
 'The Makarska Riviera is known for its stunning coastline and sailing opportunities.',
 'Sailing in Croatia offers stunning views of the Adriatic Sea.',
 "The city of Sibenik is home to the impressive St. James's Cathedral, a UNESCO World Heritage site.",
 'The island of Brač is known for its beautiful beaches and great sailing conditions.',
 'Sailing to the island of Rab, known for its medieval old town, is a great experience.',
 'The Pakleni Islands near Hvar are a popular spot for sailing yachts.',
 'The island of Cres is one of the largest in Croatia and a great destination for sailing.',
 'The island of Cres is one of the largest in Croatia and has a diverse wildlife.',
 'The city of Zagreb is the capital of Croatia and offers a mix of modern and historic attractions.',
 'Sailors can experience the traditional Dalmatian way of life in many coastal villages.',
 'The city of Knin is known for its historic fortress and beautiful scenery.',
 'The island of Krk is the largest island in the Adriatic Sea.',
 'Croatia has a rich history dating back to the Roman Empire.',
 'The island of Hvar is a popular destination for celebrities and high-end travelers.',
 'The city of Varazdin is known for its baroque buildings and vibrant cultural scene.',
 'Sailors can enjoy fresh seafood at many coastal restaurants in Croatia.',
 'The coastal town of Senj is known for its carnival and Nehaj Fortress.',
 'The Dalmatian Coast is a famous region for sailing in Croatia.',
 "The Diocletian's Palace in Split is one of the most famous Roman ruins in Croatia.",
 'The island of Dugi Otok is known for its dramatic cliffs and beautiful sailing waters.',
 'The island of Rab is famous for its medieval old town and stunning beaches.',
 'The island of Mljet is home to a national park and is ideal for nature lovers.',
 'Sailors in Croatia can visit ancient Roman ruins in Split.',
 'The city of Kotor, just across the border in Montenegro, is a popular extension for Croatian sailing trips.',
 'The island of Korcula is believed to be the birthplace of Marco Polo.',
 'The town of Motovun in Istria is famous for its film festival.',
 'The city of Nin is known for its ancient salt pans and historic church.',
 'The city of Vukovar is known for its role in the Croatian War of Independence.',
 'Sailing to the island of Lošinj, known for its health tourism, is a relaxing experience.',
 'The island of Hvar is known for its vibrant nightlife and sailing opportunities.',
 'The island of Korčula is believed to be the birthplace of Marco Polo and is a popular sailing destination.',
 'Sailing in Croatia often involves stopping at picturesque fishing villages.',
 'The city of Opatija is known for its grand villas and seaside promenade.',
 'The city of Porec is known for the Euphrasian Basilica, a UNESCO World Heritage site.',
 'The island of Brac is home to the famous Zlatni Rat beach, known for its changing shape.',
 'Sailing around the island of Mljet offers a peaceful and scenic experience.',
 'The Blue Cave on Biševo Island is a must-see for sailors.',
 'The island of Pag is famous for its cheese and nightlife, and is a fun stop for sailors.',
 "The island of Lastovo is one of Croatia's most remote and tranquil destinations.",
 'Sailors can enjoy snorkeling in the clear waters of the Adriatic Sea.',
 'The city of Rovinj is a charming starting point for a sailing trip in Croatia.',
 "Croatia's national parks, like Krka and Plitvice, are ideal for hiking and nature lovers.",
 'The city of Zadar is famous for its sunsets, which sailors can enjoy from the sea.',
 'Croatia has over a thousand islands, each with its unique charm.',
 "Croatia's Adriatic coast is dotted with charming fishing villages.",
 'Sailing to the island of Šolta offers a quiet escape from the more touristy areas.',
 'Sailors in Croatia can explore over 1,200 islands.',
 'Sailing in Croatia provides opportunities to visit ancient fortresses and castles along the coast.',
 'Croatia is famous for its beautiful coastline and crystal-clear waters.',
 'The island of Krk is accessible by bridge and is a popular starting point for sailing trips.',
 'Sailing in Croatia is best enjoyed during the summer months.',
 'The island of Pag is famous for its cheese, which is considered a delicacy.',
 'The medieval town of Rovinj is one of the most picturesque places in Croatia.',
 'The island of Losinj is famous for its health tourism and clean air.',
 'The city of Dubrovnik, with its famous city walls, is a top destination for sailors.',
 'Croatia has beautiful islands perfect for sailing.',
 'Sailing in Croatia allows you to explore hidden coves and bays.',
 'The city of Rijeka is an important cultural and economic center in Croatia.',
 'The island of Mljet has a national park that is perfect for exploring by sailboat.',
 'The Istrian Peninsula is famous for its truffles and gourmet food.',
 'The town of Cavtat is a quieter alternative to nearby Dubrovnik.',
 'The Peljesac Peninsula is known for its vineyards and wine production.',
 'The Dubrovnik Summer Festival is a major cultural event featuring theater, music, and dance performances.',
 'The city of Zadar is famous for its unique Sea Organ, an architectural sound art object.',
 'The beaches in Croatia are among the best in Europe, with many receiving Blue Flag status.',
 'Sailing around the island of Murter gives access to the Kornati Islands National Park.',
 'The city of Trogir, with its historic architecture, is a great place to dock.',
 'Sailing from Split to Dubrovnik offers breathtaking coastal scenery.',
 'The Plitvice Lakes National Park is a UNESCO World Heritage site known for its stunning waterfalls and lakes.',
 'The city of Hvar is one of the sunniest places in Europe and a popular sailing hub.',
 "The city of Dubrovnik is often called the 'Pearl of the Adriatic'.",
 'The city of Osijek is located in the eastern part of Croatia and is known for its Baroque style.',
 'The city of Pula, with its Roman amphitheater, is a unique sailing destination.',
 'The town of Trogir is a UNESCO World Heritage site known for its medieval architecture.',
 'Sailors in Croatia can enjoy local wines at many coastal vineyards.',
 'Croatia has a Mediterranean climate, making it a great destination year-round.',
 'Croatia has a diverse cultural heritage, with influences from Italy, Hungary, and Austria.',
 'The city of Rijeka is an important cultural and historical sailing destination.',
 'The best sailing routes in Croatia include Dubrovnik and Split.',
 'The Brijuni Islands are a national park and a former presidential retreat.',
 'Sailing to the Elaphiti Islands offers a mix of natural beauty and cultural sites.',
 'Croatia is known for its delicious seafood cuisine.',
 'The ancient city of Pula is known for its well-preserved Roman amphitheater.',
 'The city of Opatija is a historical seaside resort that welcomes sailors.',
 'The waters around Croatia are known for being calm and clear, ideal for sailing.',
 'The Kornati Islands National Park is a popular sailing destination in Croatia.',
 "Sailing around the Brijuni Islands offers a glimpse of Croatia's natural beauty and wildlife.",
 'The island of Vis was a military base and was closed to tourism until the 1990s.',
 'The city of Split is a major port and gateway to the Dalmatian islands.',
 'Sailing to the island of Vis provides access to the famous Blue Cave.',
 "The city of Buzet in Istria is known as the 'City of Truffles'.",
 'The city of Karlovac is known for its parks and the rivers that flow through it.',
 'Sailing to the island of Vis allows you to experience a more remote part of Croatia.',
 'The city of Šibenik is a UNESCO World Heritage site and a great stop for sailors.',
 "The town of Samobor is famous for its traditional cream cake called 'kremsnita'.",
 'Sailing around the island of Lastovo provides a more secluded experience.',
 "Croatia's wine regions produce some excellent wines, especially in Istria and Dalmatia.",
 'Many sailors start their Croatian adventure from the city of Zadar.',
 'The coastal town of Makarska is known for its beautiful beaches and lively nightlife.']

# %%
# %cd /content/drive/MyDrive/GenAI/RAG/Basics of Retrieval Systems
# Out:
# /content/drive/MyDrive/GenAI/RAG/Basics of Retrieval Systems

# %%
# Import libraries
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Download some models from nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# # Tokenization

# %%
# Sample text
text = "Sailing in Croatia between Split and Zadar is fantastic?"

# %%
# Tokenize into sentences
nltk.sent_tokenize(text)
# Out:
# ['Sailing in Croatia between Split and Zadar is fantastic?']

# %% [markdown]
# A sentence is defined when there is a '.' and an empty space after

# %%
# Tokenization into words
nltk.word_tokenize(text)
# Out:
# ['Sailing',
#  'in',
#  'Croatia',
#  'between',
#  'Split',
#  'and',
#  'Zadar',
#  'is',
#  'fantastic',
#  '?']

# %% [markdown]
# # Pre-processing

# %% [markdown]
# *   We don't capitalize. I would query 'croatia sailing' and not "Croatia Sailing'
# *   croatia is different than Croatia
# *   We don't really add punctuation

# %%
text.lower()
# Out:
# 'sailing in croatia between split and zadar is fantastic?'

# %%
def preprocess(text):
  # Lowering the capitalization
  text_lower = text.lower()

  # Tokenization into words
  tokens = nltk.word_tokenize(text_lower)

  return [word for word in tokens if word.isalnum()]

# %%
# Apply the pre-processing to the documents
preprocessed_docs = [' '.join(preprocess(doc)) for doc in documents]

# %% [markdown]
# # TF-IDF

# %%
# Creating an instance of the TF-IDF Vectorizer
vectorizer = TfidfVectorizer()

# %%
# Fit and transform the preprocessed docs
tfidf_matrix = vectorizer.fit_transform(preprocessed_docs)
print(f"The shape of the TF-IDF matrix is {tfidf_matrix.shape}")
print(f"The length of documents is {len(documents)}")
# Out:
# The shape of the TF-IDF matrix is (100, 360)
# The length of documents is 100

# %%
# Query the index
query = "croatia sailing"
query_vec = vectorizer.transform([query])
cosine_similarity(tfidf_matrix, query_vec).flatten()
# Out:
# array([0.24200283, 0.13063328, 0.28789613, 0.        , 0.13091565,
#        0.12744614, 0.11470109, 0.26443714, 0.1200554 , 0.10132357,
#        0.        , 0.        , 0.        , 0.11117943, 0.        ,
#        0.        , 0.11093168, 0.        , 0.30524835, 0.10791902,
#        0.11541319, 0.        , 0.        , 0.12321974, 0.09688848,
#        0.        , 0.        , 0.        , 0.        , 0.12483007,
#        0.14262231, 0.10472003, 0.22863442, 0.        , 0.        ,
#        0.        , 0.13059847, 0.        , 0.        , 0.1172783 ,
#        0.        , 0.24809611, 0.09509067, 0.        , 0.11325454,
#        0.12163093, 0.1050687 , 0.15612242, 0.20876142, 0.16323255,
#        0.10501606, 0.25298311, 0.        , 0.11740617, 0.        ,
#        0.        , 0.34633262, 0.22806771, 0.11765747, 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.09094918, 0.11309818, 0.        , 0.12986737, 0.        ,
#        0.11295693, 0.        , 0.10234293, 0.13411726, 0.        ,
#        0.11227415, 0.12125818, 0.10208762, 0.13088904, 0.26976637,
#        0.        , 0.11454866, 0.15024217, 0.        , 0.        ,
#        0.22376085, 0.28947714, 0.22705354, 0.        , 0.        ,
#        0.11981942, 0.        , 0.        , 0.21291946, 0.        ,
#        0.        , 0.13147867, 0.09577011, 0.        , 0.        ])

# %%
# Sort the documents by similarity to the query
similarities = cosine_similarity(tfidf_matrix, query_vec).flatten()
sorted_similarities = list(enumerate(similarities))
sorted(sorted_similarities, key=lambda x: x[1], reverse=True)
# Out:
# [(56, np.float64(0.3463326177734656)),
#  (18, np.float64(0.30524834901003683)),
#  (86, np.float64(0.289477144161549)),
#  (2, np.float64(0.2878961250809324)),
#  (79, np.float64(0.2697663666536758)),
#  (7, np.float64(0.26443714198277574)),
#  (51, np.float64(0.2529831093224971)),
#  (41, np.float64(0.24809611448223312)),
#  (0, np.float64(0.24200282597100126)),
#  (32, np.float64(0.22863442162734365)),
#  (57, np.float64(0.22806770911560081)),
#  (87, np.float64(0.22705354408637923)),
#  (85, np.float64(0.22376084862387863)),
#  (93, np.float64(0.21291946178423374)),
#  (48, np.float64(0.20876142357900254)),
#  (49, np.float64(0.1632325463490037)),
#  (47, np.float64(0.1561224238877196)),
#  (82, np.float64(0.15024216891927034)),
#  (30, np.float64(0.14262231277766355)),
#  (73, np.float64(0.1341172613847461)),
#  (96, np.float64(0.13147866648060116)),
#  (4, np.float64(0.13091564915907272)),
#  (78, np.float64(0.13088904245703745)),
#  (1, np.float64(0.13063327992289878)),
#  (36, np.float64(0.13059846989505045)),
#  (68, np.float64(0.12986737471906057)),
#  (5, np.float64(0.12744613919344638)),
#  (29, np.float64(0.12483007236047007)),
#  (23, np.float64(0.12321973759820973)),
#  (45, np.float64(0.12163092541462699)),
#  (76, np.float64(0.12125817645167508)),
#  (8, np.float64(0.12005539867434271)),
#  (90, np.float64(0.11981941859362374)),
#  (58, np.float64(0.11765746750500053)),
#  (53, np.float64(0.11740616543771365)),
#  (39, np.float64(0.11727830167035747)),
#  (20, np.float64(0.11541319037346488)),
#  (6, np.float64(0.11470108730952823)),
#  (81, np.float64(0.11454866136363852)),
#  (44, np.float64(0.1132545369505073)),
#  (66, np.float64(0.11309818193526716)),
#  (70, np.float64(0.1129569282896039)),
#  (75, np.float64(0.11227415246287376)),
#  (13, np.float64(0.11117942940045264)),
#  (16, np.float64(0.1109316825810146)),
#  (19, np.float64(0.10791901765546799)),
#  (46, np.float64(0.1050687012310533)),
#  (50, np.float64(0.10501606213537165)),
#  (31, np.float64(0.10472003325540194)),
#  (72, np.float64(0.10234293486728112)),
#  (77, np.float64(0.10208762434223217)),
#  (9, np.float64(0.10132357482102752)),
#  (24, np.float64(0.09688848166053413)),
#  (97, np.float64(0.09577011177834506)),
#  (42, np.float64(0.09509066829897503)),
#  (65, np.float64(0.09094918172306897)),
#  (3, np.float64(0.0)),
#  (10, np.float64(0.0)),
#  (11, np.float64(0.0)),
#  (12, np.float64(0.0)),
#  (14, np.float64(0.0)),
#  (15, np.float64(0.0)),
#  (17, np.float64(0.0)),
#  (21, np.float64(0.0)),
#  (22, np.float64(0.0)),
#  (25, np.float64(0.0)),
#  (26, np.float64(0.0)),
#  (27, np.float64(0.0)),
#  (28, np.float64(0.0)),
#  (33, np.float64(0.0)),
#  (34, np.float64(0.0)),
#  (35, np.float64(0.0)),
#  (37, np.float64(0.0)),
#  (38, np.float64(0.0)),
#  (40, np.float64(0.0)),
#  (43, np.float64(0.0)),
#  (52, np.float64(0.0)),
#  (54, np.float64(0.0)),
#  (55, np.float64(0.0)),
#  (59, np.float64(0.0)),
#  (60, np.float64(0.0)),
#  (61, np.float64(0.0)),
#  (62, np.float64(0.0)),
#  (63, np.float64(0.0)),
#  (64, np.float64(0.0)),
#  (67, np.float64(0.0)),
#  (69, np.float64(0.0)),
#  (71, np.float64(0.0)),
#  (74, np.float64(0.0)),
#  (80, np.float64(0.0)),
#  (83, np.float64(0.0)),
#  (84, np.float64(0.0)),
#  (88, np.float64(0.0)),
#  (89, np.float64(0.0)),
#  (91, np.float64(0.0)),
#  (92, np.float64(0.0)),
#  (94, np.float64(0.0)),
#  (95, np.float64(0.0)),
#  (98, np.float64(0.0)),
#  (99, np.float64(0.0))]

# %%
# Build a function to search with TF-IDF
def search_tfidf(query, vectorizer, tfidf_matrix):
  # Vectorizing the query
  query_vec = vectorizer.transform([query])

  # Compute the Cosine similarity
  similarities = cosine_similarity(tfidf_matrix, query_vec).flatten()

  # Pair each document index with its similarity score
  sorted_similarities = list(enumerate(similarities))

  # Sort the documents by similarity score
  results = sorted(sorted_similarities, key=lambda x: x[1], reverse=True)

  return results

# %%
# Apply the function to the query
search_similarities = search_tfidf(query, vectorizer, tfidf_matrix)

# Print out the top 10 documents by similariry score
print(f"Top 10 documents by similarity score for query {query}:")
for doc_index, score in search_similarities[:10]:
  print(f"Document {doc_index + 1}: {documents[doc_index]}")
# Out:
# Top 10 documents by similarity score for query croatia sailing:
# Document 57: Croatia has beautiful islands perfect for sailing.
# Document 19: The Dalmatian Coast is a famous region for sailing in Croatia.
# Document 87: The Kornati Islands National Park is a popular sailing destination in Croatia.
# Document 3: Sailing in Croatia offers stunning views of the Adriatic Sea.
# Document 80: The best sailing routes in Croatia include Dubrovnik and Split.
# Document 8: The island of Cres is one of the largest in Croatia and a great destination for sailing.
# Document 52: Sailing in Croatia is best enjoyed during the summer months.
# Document 42: The city of Rovinj is a charming starting point for a sailing trip in Croatia.
# Document 1: Sailing in Croatia often includes visiting UNESCO World Heritage sites.
# Document 33: Sailing in Croatia often involves stopping at picturesque fishing villages.

# %% [markdown]
# # Boolean

# %%
# !pip install whoosh -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 4.8 MB/s eta 0:00:00

# %%
# Import libraries
import os
import shutil
from whoosh.index import create_in
from whoosh.fields import *
from whoosh.qparser import QueryParser

# %%
# Preprocessing Text part 2
def preprocess2(text):
  # Lowering the capitalization
  text_lower = text.lower()

  # Tokenization into words
  tokens = nltk.word_tokenize(text_lower)

  # List the tokens per document
  tokens = [word for word in tokens if word.isalnum()]

  # Defining the English Stopwords
  stopwords = set(nltk.corpus.stopwords.words('english')) - {"and", "or", "not"}

  # Removing the stopwords
  tokens = [word for word in tokens if word not in stopwords]

  return tokens

# Apply the function and test it
print(text)
preprocess2(text)
# Out:
# Sailing in Croatia between Split and Zadar is fantastic?
# ['sailing', 'croatia', 'split', 'and', 'zadar', 'fantastic']

# %%
# Create a new folder, remove the old one if available
if os.path.exists("index_dir"):
  shutil.rmtree("index_dir")
os.mkdir("index_dir")

# %%
# Define a schema for the directory
schema = Schema(title = ID(stored = True,
                           unique = True),
                content = TEXT(stored = True))

# %%
# Create the index in the folder
index = create_in("index_dir", schema)

# %%
# Add documents by writing to the index
writer = index.writer()
for i, doc in enumerate(documents):
  writer.add_document(title = str(i),
                      content = preprocess2(doc))
writer.commit()

# %%
# Query using boolean
query = "croatia NOT sailing"

# %%
# Create a QueryParser that targets the content field
parser = QueryParser("content", schema = index.schema)

# Parse the user's query
parsed_query = parser.parse(query)
print(f"Parsed query: {parsed_query}")

# Open the directory and perform the query / search
with index.searcher() as searcher:
  results = searcher.search(parsed_query)
  print([[hit["title"], hit['content']] for hit in results])
# Out:
# Parsed query: (content:croatia AND NOT content:sailing)
# [['47', ['sailors', 'croatia', 'explore', 'islands']], ['44', ['croatia', 'thousand', 'islands', 'unique', 'charm']], ['82', ['croatia', 'known', 'delicious', 'seafood', 'cuisine']], ['49', ['croatia', 'famous', 'beautiful', 'coastline', 'and', 'waters']], ['76', ['croatia', 'mediterranean', 'climate', 'making', 'great', 'destination']], ['13', ['croatia', 'rich', 'history', 'dating', 'back', 'roman', 'empire']], ['23', ['sailors', 'croatia', 'visit', 'ancient', 'roman', 'ruins', 'split']], ['45', ['croatia', 'adriatic', 'coast', 'dotted', 'charming', 'fishing', 'villages']], ['53', ['medieval', 'town', 'rovinj', 'one', 'picturesque', 'places', 'croatia']], ['8', ['island', 'cres', 'one', 'largest', 'croatia', 'and', 'diverse', 'wildlife']]]

# %%
# Build  a function for boolean dearch
def boolean_search(query, index):
  # Create a QueryParser that targets the content field
  parser = QueryParser("content", schema = index.schema)

  # Parse the user's query
  parsed_query = parser.parse(query)
  print(f"Parsed query: {parsed_query}")

  # Open the directory and perform the query / search
  with index.searcher() as searcher:
    results = searcher.search(parsed_query)
    return [(hit["title"], hit['content']) for hit in results]

# %%
# Apply the function
boolean_search(query, index)
# Out:
# Parsed query: (content:croatia AND NOT content:sailing)
# [('47', ['sailors', 'croatia', 'explore', 'islands']),
#  ('44', ['croatia', 'thousand', 'islands', 'unique', 'charm']),
#  ('82', ['croatia', 'known', 'delicious', 'seafood', 'cuisine']),
#  ('49', ['croatia', 'famous', 'beautiful', 'coastline', 'and', 'waters']),
#  ('76',
#   ['croatia', 'mediterranean', 'climate', 'making', 'great', 'destination']),
#  ('13', ['croatia', 'rich', 'history', 'dating', 'back', 'roman', 'empire']),
#  ('23', ['sailors', 'croatia', 'visit', 'ancient', 'roman', 'ruins', 'split']),
#  ('45',
#   ['croatia',
#    'adriatic',
#    'coast',
#    'dotted',
#    'charming',
#    'fishing',
#    'villages']),
#  ('53',
#   ['medieval', 'town', 'rovinj', 'one', 'picturesque', 'places', 'croatia']),
#  ('8',
#   ['island',
#    'cres',
#    'one',
#    'largest',
#    'croatia',
#    'and',
#    'diverse',
#    'wildlife'])]

# %% [markdown]
# # Probabilistic Retrieval Model

# %%
# !pip install rank_bm25 -q

# %%
# Import the BM25 class
from rank_bm25 import BM25Okapi

# %%
# Tokenize the documents
tokenized_docs = [preprocess(doc) for doc in documents]
tokenized_docs
# Out:
# [['sailing',
#   'in',
#   'croatia',
#   'often',
#   'includes',
#   'visiting',
#   'unesco',
#   'world',
#   'heritage',
#   'sites'],
#  ['the',
#   'makarska',
#   'riviera',
#   'is',
#   'known',
#   'for',
#   'its',
#   'stunning',
#   'coastline',
#   'and',
#   'sailing',
#   'opportunities'],
#  ['sailing',
#   'in',
#   'croatia',
#   'offers',
#   'stunning',
#   'views',
#   'of',
#   'the',
#   'adriatic',
#   'sea'],
#  ['the',
#   'city',
#   'of',
#   'sibenik',
#   'is',
#   'home',
#   'to',
#   'the',
#   'impressive',
#   'james',
#   'cathedral',
#   'a',
#   'unesco',
#   'world',
#   'heritage',
#   'site'],
#  ['the',
#   'island',
#   'of',
#   'brač',
#   'is',
#   'known',
#   'for',
#   'its',
#   'beautiful',
#   'beaches',
#   'and',
#   'great',
#   'sailing',
#   'conditions'],
#  ['sailing',
#   'to',
#   'the',
#   'island',
#   'of',
#   'rab',
#   'known',
#   'for',
#   'its',
#   'medieval',
#   'old',
#   'town',
#   'is',
#   'a',
#   'great',
#   'experience'],
#  ['the',
#   'pakleni',
#   'islands',
#   'near',
#   'hvar',
#   'are',
#   'a',
#   'popular',
#   'spot',
#   'for',
#   'sailing',
#   'yachts'],
#  ['the',
#   'island',
#   'of',
#   'cres',
#   'is',
#   'one',
#   'of',
#   'the',
#   'largest',
#   'in',
#   'croatia',
#   'and',
#   'a',
#   'great',
#   'destination',
#   'for',
#   'sailing'],
#  ['the',
#   'island',
#   'of',
#   'cres',
#   'is',
#   'one',
#   'of',
#   'the',
#   'largest',
#   'in',
#   'croatia',
#   'and',
#   'has',
#   'a',
#   'diverse',
#   'wildlife'],
#  ['the',
#   'city',
#   'of',
#   'zagreb',
#   'is',
#   'the',
#   'capital',
#   'of',
#   'croatia',
#   'and',
#   'offers',
#   'a',
#   'mix',
#   'of',
#   'modern',
#   'and',
#   'historic',
#   'attractions'],
#  ['sailors',
#   'can',
#   'experience',
#   'the',
#   'traditional',
#   'dalmatian',
#   'way',
#   'of',
#   'life',
#   'in',
#   'many',
#   'coastal',
#   'villages'],
#  ['the',
#   'city',
#   'of',
#   'knin',
#   'is',
#   'known',
#   'for',
#   'its',
#   'historic',
#   'fortress',
#   'and',
#   'beautiful',
#   'scenery'],
#  ['the',
#   'island',
#   'of',
#   'krk',
#   'is',
#   'the',
#   'largest',
#   'island',
#   'in',
#   'the',
#   'adriatic',
#   'sea'],
#  ['croatia',
#   'has',
#   'a',
#   'rich',
#   'history',
#   'dating',
#   'back',
#   'to',
#   'the',
#   'roman',
#   'empire'],
#  ['the',
#   'island',
#   'of',
#   'hvar',
#   'is',
#   'a',
#   'popular',
#   'destination',
#   'for',
#   'celebrities',
#   'and',
#   'travelers'],
#  ['the',
#   'city',
#   'of',
#   'varazdin',
#   'is',
#   'known',
#   'for',
#   'its',
#   'baroque',
#   'buildings',
#   'and',
#   'vibrant',
#   'cultural',
#   'scene'],
#  ['sailors',
#   'can',
#   'enjoy',
#   'fresh',
#   'seafood',
#   'at',
#   'many',
#   'coastal',
#   'restaurants',
#   'in',
#   'croatia'],
#  ['the',
#   'coastal',
#   'town',
#   'of',
#   'senj',
#   'is',
#   'known',
#   'for',
#   'its',
#   'carnival',
#   'and',
#   'nehaj',
#   'fortress'],
#  ['the',
#   'dalmatian',
#   'coast',
#   'is',
#   'a',
#   'famous',
#   'region',
#   'for',
#   'sailing',
#   'in',
#   'croatia'],
#  ['the',
#   'diocletian',
#   'palace',
#   'in',
#   'split',
#   'is',
#   'one',
#   'of',
#   'the',
#   'most',
#   'famous',
#   'roman',
#   'ruins',
#   'in',
#   'croatia'],
#  ['the',
#   'island',
#   'of',
#   'dugi',
#   'otok',
#   'is',
#   'known',
#   'for',
#   'its',
#   'dramatic',
#   'cliffs',
#   'and',
#   'beautiful',
#   'sailing',
#   'waters'],
#  ['the',
#   'island',
#   'of',
#   'rab',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'medieval',
#   'old',
#   'town',
#   'and',
#   'stunning',
#   'beaches'],
#  ['the',
#   'island',
#   'of',
#   'mljet',
#   'is',
#   'home',
#   'to',
#   'a',
#   'national',
#   'park',
#   'and',
#   'is',
#   'ideal',
#   'for',
#   'nature',
#   'lovers'],
#  ['sailors',
#   'in',
#   'croatia',
#   'can',
#   'visit',
#   'ancient',
#   'roman',
#   'ruins',
#   'in',
#   'split'],
#  ['the',
#   'city',
#   'of',
#   'kotor',
#   'just',
#   'across',
#   'the',
#   'border',
#   'in',
#   'montenegro',
#   'is',
#   'a',
#   'popular',
#   'extension',
#   'for',
#   'croatian',
#   'sailing',
#   'trips'],
#  ['the',
#   'island',
#   'of',
#   'korcula',
#   'is',
#   'believed',
#   'to',
#   'be',
#   'the',
#   'birthplace',
#   'of',
#   'marco',
#   'polo'],
#  ['the',
#   'town',
#   'of',
#   'motovun',
#   'in',
#   'istria',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'film',
#   'festival'],
#  ['the',
#   'city',
#   'of',
#   'nin',
#   'is',
#   'known',
#   'for',
#   'its',
#   'ancient',
#   'salt',
#   'pans',
#   'and',
#   'historic',
#   'church'],
#  ['the',
#   'city',
#   'of',
#   'vukovar',
#   'is',
#   'known',
#   'for',
#   'its',
#   'role',
#   'in',
#   'the',
#   'croatian',
#   'war',
#   'of',
#   'independence'],
#  ['sailing',
#   'to',
#   'the',
#   'island',
#   'of',
#   'lošinj',
#   'known',
#   'for',
#   'its',
#   'health',
#   'tourism',
#   'is',
#   'a',
#   'relaxing',
#   'experience'],
#  ['the',
#   'island',
#   'of',
#   'hvar',
#   'is',
#   'known',
#   'for',
#   'its',
#   'vibrant',
#   'nightlife',
#   'and',
#   'sailing',
#   'opportunities'],
#  ['the',
#   'island',
#   'of',
#   'korčula',
#   'is',
#   'believed',
#   'to',
#   'be',
#   'the',
#   'birthplace',
#   'of',
#   'marco',
#   'polo',
#   'and',
#   'is',
#   'a',
#   'popular',
#   'sailing',
#   'destination'],
#  ['sailing',
#   'in',
#   'croatia',
#   'often',
#   'involves',
#   'stopping',
#   'at',
#   'picturesque',
#   'fishing',
#   'villages'],
#  ['the',
#   'city',
#   'of',
#   'opatija',
#   'is',
#   'known',
#   'for',
#   'its',
#   'grand',
#   'villas',
#   'and',
#   'seaside',
#   'promenade'],
#  ['the',
#   'city',
#   'of',
#   'porec',
#   'is',
#   'known',
#   'for',
#   'the',
#   'euphrasian',
#   'basilica',
#   'a',
#   'unesco',
#   'world',
#   'heritage',
#   'site'],
#  ['the',
#   'island',
#   'of',
#   'brac',
#   'is',
#   'home',
#   'to',
#   'the',
#   'famous',
#   'zlatni',
#   'rat',
#   'beach',
#   'known',
#   'for',
#   'its',
#   'changing',
#   'shape'],
#  ['sailing',
#   'around',
#   'the',
#   'island',
#   'of',
#   'mljet',
#   'offers',
#   'a',
#   'peaceful',
#   'and',
#   'scenic',
#   'experience'],
#  ['the',
#   'blue',
#   'cave',
#   'on',
#   'biševo',
#   'island',
#   'is',
#   'a',
#   'for',
#   'sailors'],
#  ['the',
#   'island',
#   'of',
#   'pag',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'cheese',
#   'and',
#   'nightlife',
#   'and',
#   'is',
#   'a',
#   'fun',
#   'stop',
#   'for',
#   'sailors'],
#  ['the',
#   'island',
#   'of',
#   'lastovo',
#   'is',
#   'one',
#   'of',
#   'croatia',
#   'most',
#   'remote',
#   'and',
#   'tranquil',
#   'destinations'],
#  ['sailors',
#   'can',
#   'enjoy',
#   'snorkeling',
#   'in',
#   'the',
#   'clear',
#   'waters',
#   'of',
#   'the',
#   'adriatic',
#   'sea'],
#  ['the',
#   'city',
#   'of',
#   'rovinj',
#   'is',
#   'a',
#   'charming',
#   'starting',
#   'point',
#   'for',
#   'a',
#   'sailing',
#   'trip',
#   'in',
#   'croatia'],
#  ['croatia',
#   'national',
#   'parks',
#   'like',
#   'krka',
#   'and',
#   'plitvice',
#   'are',
#   'ideal',
#   'for',
#   'hiking',
#   'and',
#   'nature',
#   'lovers'],
#  ['the',
#   'city',
#   'of',
#   'zadar',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'sunsets',
#   'which',
#   'sailors',
#   'can',
#   'enjoy',
#   'from',
#   'the',
#   'sea'],
#  ['croatia',
#   'has',
#   'over',
#   'a',
#   'thousand',
#   'islands',
#   'each',
#   'with',
#   'its',
#   'unique',
#   'charm'],
#  ['croatia',
#   'adriatic',
#   'coast',
#   'is',
#   'dotted',
#   'with',
#   'charming',
#   'fishing',
#   'villages'],
#  ['sailing',
#   'to',
#   'the',
#   'island',
#   'of',
#   'šolta',
#   'offers',
#   'a',
#   'quiet',
#   'escape',
#   'from',
#   'the',
#   'more',
#   'touristy',
#   'areas'],
#  ['sailors', 'in', 'croatia', 'can', 'explore', 'over', 'islands'],
#  ['sailing',
#   'in',
#   'croatia',
#   'provides',
#   'opportunities',
#   'to',
#   'visit',
#   'ancient',
#   'fortresses',
#   'and',
#   'castles',
#   'along',
#   'the',
#   'coast'],
#  ['croatia',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'beautiful',
#   'coastline',
#   'and',
#   'waters'],
#  ['the',
#   'island',
#   'of',
#   'krk',
#   'is',
#   'accessible',
#   'by',
#   'bridge',
#   'and',
#   'is',
#   'a',
#   'popular',
#   'starting',
#   'point',
#   'for',
#   'sailing',
#   'trips'],
#  ['sailing',
#   'in',
#   'croatia',
#   'is',
#   'best',
#   'enjoyed',
#   'during',
#   'the',
#   'summer',
#   'months'],
#  ['the',
#   'island',
#   'of',
#   'pag',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'cheese',
#   'which',
#   'is',
#   'considered',
#   'a',
#   'delicacy'],
#  ['the',
#   'medieval',
#   'town',
#   'of',
#   'rovinj',
#   'is',
#   'one',
#   'of',
#   'the',
#   'most',
#   'picturesque',
#   'places',
#   'in',
#   'croatia'],
#  ['the',
#   'island',
#   'of',
#   'losinj',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'health',
#   'tourism',
#   'and',
#   'clean',
#   'air'],
#  ['the',
#   'city',
#   'of',
#   'dubrovnik',
#   'with',
#   'its',
#   'famous',
#   'city',
#   'walls',
#   'is',
#   'a',
#   'top',
#   'destination',
#   'for',
#   'sailors'],
#  ['croatia', 'has', 'beautiful', 'islands', 'perfect', 'for', 'sailing'],
#  ['sailing',
#   'in',
#   'croatia',
#   'allows',
#   'you',
#   'to',
#   'explore',
#   'hidden',
#   'coves',
#   'and',
#   'bays'],
#  ['the',
#   'city',
#   'of',
#   'rijeka',
#   'is',
#   'an',
#   'important',
#   'cultural',
#   'and',
#   'economic',
#   'center',
#   'in',
#   'croatia'],
#  ['the',
#   'island',
#   'of',
#   'mljet',
#   'has',
#   'a',
#   'national',
#   'park',
#   'that',
#   'is',
#   'perfect',
#   'for',
#   'exploring',
#   'by',
#   'sailboat'],
#  ['the',
#   'istrian',
#   'peninsula',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'truffles',
#   'and',
#   'gourmet',
#   'food'],
#  ['the',
#   'town',
#   'of',
#   'cavtat',
#   'is',
#   'a',
#   'quieter',
#   'alternative',
#   'to',
#   'nearby',
#   'dubrovnik'],
#  ['the',
#   'peljesac',
#   'peninsula',
#   'is',
#   'known',
#   'for',
#   'its',
#   'vineyards',
#   'and',
#   'wine',
#   'production'],
#  ['the',
#   'dubrovnik',
#   'summer',
#   'festival',
#   'is',
#   'a',
#   'major',
#   'cultural',
#   'event',
#   'featuring',
#   'theater',
#   'music',
#   'and',
#   'dance',
#   'performances'],
#  ['the',
#   'city',
#   'of',
#   'zadar',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'unique',
#   'sea',
#   'organ',
#   'an',
#   'architectural',
#   'sound',
#   'art',
#   'object'],
#  ['the',
#   'beaches',
#   'in',
#   'croatia',
#   'are',
#   'among',
#   'the',
#   'best',
#   'in',
#   'europe',
#   'with',
#   'many',
#   'receiving',
#   'blue',
#   'flag',
#   'status'],
#  ['sailing',
#   'around',
#   'the',
#   'island',
#   'of',
#   'murter',
#   'gives',
#   'access',
#   'to',
#   'the',
#   'kornati',
#   'islands',
#   'national',
#   'park'],
#  ['the',
#   'city',
#   'of',
#   'trogir',
#   'with',
#   'its',
#   'historic',
#   'architecture',
#   'is',
#   'a',
#   'great',
#   'place',
#   'to',
#   'dock'],
#  ['sailing',
#   'from',
#   'split',
#   'to',
#   'dubrovnik',
#   'offers',
#   'breathtaking',
#   'coastal',
#   'scenery'],
#  ['the',
#   'plitvice',
#   'lakes',
#   'national',
#   'park',
#   'is',
#   'a',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'known',
#   'for',
#   'its',
#   'stunning',
#   'waterfalls',
#   'and',
#   'lakes'],
#  ['the',
#   'city',
#   'of',
#   'hvar',
#   'is',
#   'one',
#   'of',
#   'the',
#   'sunniest',
#   'places',
#   'in',
#   'europe',
#   'and',
#   'a',
#   'popular',
#   'sailing',
#   'hub'],
#  ['the',
#   'city',
#   'of',
#   'dubrovnik',
#   'is',
#   'often',
#   'called',
#   'the',
#   'of',
#   'the',
#   'adriatic'],
#  ['the',
#   'city',
#   'of',
#   'osijek',
#   'is',
#   'located',
#   'in',
#   'the',
#   'eastern',
#   'part',
#   'of',
#   'croatia',
#   'and',
#   'is',
#   'known',
#   'for',
#   'its',
#   'baroque',
#   'style'],
#  ['the',
#   'city',
#   'of',
#   'pula',
#   'with',
#   'its',
#   'roman',
#   'amphitheater',
#   'is',
#   'a',
#   'unique',
#   'sailing',
#   'destination'],
#  ['the',
#   'town',
#   'of',
#   'trogir',
#   'is',
#   'a',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'known',
#   'for',
#   'its',
#   'medieval',
#   'architecture'],
#  ['sailors',
#   'in',
#   'croatia',
#   'can',
#   'enjoy',
#   'local',
#   'wines',
#   'at',
#   'many',
#   'coastal',
#   'vineyards'],
#  ['croatia',
#   'has',
#   'a',
#   'mediterranean',
#   'climate',
#   'making',
#   'it',
#   'a',
#   'great',
#   'destination'],
#  ['croatia',
#   'has',
#   'a',
#   'diverse',
#   'cultural',
#   'heritage',
#   'with',
#   'influences',
#   'from',
#   'italy',
#   'hungary',
#   'and',
#   'austria'],
#  ['the',
#   'city',
#   'of',
#   'rijeka',
#   'is',
#   'an',
#   'important',
#   'cultural',
#   'and',
#   'historical',
#   'sailing',
#   'destination'],
#  ['the',
#   'best',
#   'sailing',
#   'routes',
#   'in',
#   'croatia',
#   'include',
#   'dubrovnik',
#   'and',
#   'split'],
#  ['the',
#   'brijuni',
#   'islands',
#   'are',
#   'a',
#   'national',
#   'park',
#   'and',
#   'a',
#   'former',
#   'presidential',
#   'retreat'],
#  ['sailing',
#   'to',
#   'the',
#   'elaphiti',
#   'islands',
#   'offers',
#   'a',
#   'mix',
#   'of',
#   'natural',
#   'beauty',
#   'and',
#   'cultural',
#   'sites'],
#  ['croatia', 'is', 'known', 'for', 'its', 'delicious', 'seafood', 'cuisine'],
#  ['the',
#   'ancient',
#   'city',
#   'of',
#   'pula',
#   'is',
#   'known',
#   'for',
#   'its',
#   'roman',
#   'amphitheater'],
#  ['the',
#   'city',
#   'of',
#   'opatija',
#   'is',
#   'a',
#   'historical',
#   'seaside',
#   'resort',
#   'that',
#   'welcomes',
#   'sailors'],
#  ['the',
#   'waters',
#   'around',
#   'croatia',
#   'are',
#   'known',
#   'for',
#   'being',
#   'calm',
#   'and',
#   'clear',
#   'ideal',
#   'for',
#   'sailing'],
#  ['the',
#   'kornati',
#   'islands',
#   'national',
#   'park',
#   'is',
#   'a',
#   'popular',
#   'sailing',
#   'destination',
#   'in',
#   'croatia'],
#  ['sailing',
#   'around',
#   'the',
#   'brijuni',
#   'islands',
#   'offers',
#   'a',
#   'glimpse',
#   'of',
#   'croatia',
#   'natural',
#   'beauty',
#   'and',
#   'wildlife'],
#  ['the',
#   'island',
#   'of',
#   'vis',
#   'was',
#   'a',
#   'military',
#   'base',
#   'and',
#   'was',
#   'closed',
#   'to',
#   'tourism',
#   'until',
#   'the',
#   '1990s'],
#  ['the',
#   'city',
#   'of',
#   'split',
#   'is',
#   'a',
#   'major',
#   'port',
#   'and',
#   'gateway',
#   'to',
#   'the',
#   'dalmatian',
#   'islands'],
#  ['sailing',
#   'to',
#   'the',
#   'island',
#   'of',
#   'vis',
#   'provides',
#   'access',
#   'to',
#   'the',
#   'famous',
#   'blue',
#   'cave'],
#  ['the',
#   'city',
#   'of',
#   'buzet',
#   'in',
#   'istria',
#   'is',
#   'known',
#   'as',
#   'the',
#   'of',
#   'truffles'],
#  ['the',
#   'city',
#   'of',
#   'karlovac',
#   'is',
#   'known',
#   'for',
#   'its',
#   'parks',
#   'and',
#   'the',
#   'rivers',
#   'that',
#   'flow',
#   'through',
#   'it'],
#  ['sailing',
#   'to',
#   'the',
#   'island',
#   'of',
#   'vis',
#   'allows',
#   'you',
#   'to',
#   'experience',
#   'a',
#   'more',
#   'remote',
#   'part',
#   'of',
#   'croatia'],
#  ['the',
#   'city',
#   'of',
#   'šibenik',
#   'is',
#   'a',
#   'unesco',
#   'world',
#   'heritage',
#   'site',
#   'and',
#   'a',
#   'great',
#   'stop',
#   'for',
#   'sailors'],
#  ['the',
#   'town',
#   'of',
#   'samobor',
#   'is',
#   'famous',
#   'for',
#   'its',
#   'traditional',
#   'cream',
#   'cake',
#   'called'],
#  ['sailing',
#   'around',
#   'the',
#   'island',
#   'of',
#   'lastovo',
#   'provides',
#   'a',
#   'more',
#   'secluded',
#   'experience'],
#  ['croatia',
#   'wine',
#   'regions',
#   'produce',
#   'some',
#   'excellent',
#   'wines',
#   'especially',
#   'in',
#   'istria',
#   'and',
#   'dalmatia'],
#  ['many',
#   'sailors',
#   'start',
#   'their',
#   'croatian',
#   'adventure',
#   'from',
#   'the',
#   'city',
#   'of',
#   'zadar'],
#  ['the',
#   'coastal',
#   'town',
#   'of',
#   'makarska',
#   'is',
#   'known',
#   'for',
#   'its',
#   'beautiful',
#   'beaches',
#   'and',
#   'lively',
#   'nightlife']]

# %%
# Initialize the BM25 Model
bm25 = BM25Okapi(tokenized_docs)

# %%
# Start the Probabilist search
query = "croatia sailing"

# Build a function
def search_bm25(query, bm25):
  tokenized_query = preprocess(query)
  results = bm25.get_scores(tokenized_query)
  return results

# %%
# Perform the BM25 search
results = search_bm25(query, bm25)

# Sort the documents by relevance to the query
np.argsort(results)[::-1]

# Print the documents
for i in np.argsort(results)[::-1]:
  print(f"Document {i + 1}: {documents[i]}")
# Out:
# Document 57: Croatia has beautiful islands perfect for sailing.
# Document 1: Sailing in Croatia often includes visiting UNESCO World Heritage sites.
# Document 3: Sailing in Croatia offers stunning views of the Adriatic Sea.
# Document 33: Sailing in Croatia often involves stopping at picturesque fishing villages.
# Document 80: The best sailing routes in Croatia include Dubrovnik and Split.
# Document 52: Sailing in Croatia is best enjoyed during the summer months.
# Document 19: The Dalmatian Coast is a famous region for sailing in Croatia.
# Document 58: Sailing in Croatia allows you to explore hidden coves and bays.
# Document 87: The Kornati Islands National Park is a popular sailing destination in Croatia.
# Document 49: Sailing in Croatia provides opportunities to visit ancient fortresses and castles along the coast.
# Document 88: Sailing around the Brijuni Islands offers a glimpse of Croatia's natural beauty and wildlife.
# Document 86: The waters around Croatia are known for being calm and clear, ideal for sailing.
# Document 42: The city of Rovinj is a charming starting point for a sailing trip in Croatia.
# Document 94: Sailing to the island of Vis allows you to experience a more remote part of Croatia.
# Document 8: The island of Cres is one of the largest in Croatia and a great destination for sailing.
# Document 48: Sailors in Croatia can explore over 1,200 islands.
# Document 69: Sailing from Split to Dubrovnik offers breathtaking coastal scenery.
# Document 83: Croatia is known for its delicious seafood cuisine.
# Document 46: Croatia's Adriatic coast is dotted with charming fishing villages.
# Document 50: Croatia is famous for its beautiful coastline and crystal-clear waters.
# Document 97: Sailing around the island of Lastovo provides a more secluded experience.
# Document 77: Croatia has a Mediterranean climate, making it a great destination year-round.
# Document 24: Sailors in Croatia can visit ancient Roman ruins in Split.
# Document 2: The Makarska Riviera is known for its stunning coastline and sailing opportunities.
# Document 7: The Pakleni Islands near Hvar are a popular spot for sailing yachts.
# Document 79: The city of Rijeka is an important cultural and historical sailing destination.
# Document 37: Sailing around the island of Mljet offers a peaceful and scenic experience.
# Document 74: The city of Pula, with its Roman amphitheater, is a unique sailing destination.
# Document 91: Sailing to the island of Vis provides access to the famous Blue Cave.
# Document 31: The island of Hvar is known for its vibrant nightlife and sailing opportunities.
# Document 76: Sailors in Croatia can enjoy local wines at many coastal vineyards.
# Document 14: Croatia has a rich history dating back to the Roman Empire.
# Document 45: Croatia has over a thousand islands, each with its unique charm.
# Document 17: Sailors can enjoy fresh seafood at many coastal restaurants in Croatia.
# Document 82: Sailing to the Elaphiti Islands offers a mix of natural beauty and cultural sites.
# Document 5: The island of Brač is known for its beautiful beaches and great sailing conditions.
# Document 67: Sailing around the island of Murter gives access to the Kornati Islands National Park.
# Document 98: Croatia's wine regions produce some excellent wines, especially in Istria and Dalmatia.
# Document 21: The island of Dugi Otok is known for its dramatic cliffs and beautiful sailing waters.
# Document 47: Sailing to the island of Šolta offers a quiet escape from the more touristy areas.
# Document 30: Sailing to the island of Lošinj, known for its health tourism, is a relaxing experience.
# Document 40: The island of Lastovo is one of Croatia's most remote and tranquil destinations.
# Document 59: The city of Rijeka is an important cultural and economic center in Croatia.
# Document 78: Croatia has a diverse cultural heritage, with influences from Italy, Hungary, and Austria.
# Document 6: Sailing to the island of Rab, known for its medieval old town, is a great experience.
# Document 43: Croatia's national parks, like Krka and Plitvice, are ideal for hiking and nature lovers.
# Document 54: The medieval town of Rovinj is one of the most picturesque places in Croatia.
# Document 71: The city of Hvar is one of the sunniest places in Europe and a popular sailing hub.
# Document 51: The island of Krk is accessible by bridge and is a popular starting point for sailing trips.
# Document 20: The Diocletian's Palace in Split is one of the most famous Roman ruins in Croatia.
# Document 25: The city of Kotor, just across the border in Montenegro, is a popular extension for Croatian sailing trips.
# Document 9: The island of Cres is one of the largest in Croatia and has a diverse wildlife.
# Document 66: The beaches in Croatia are among the best in Europe, with many receiving Blue Flag status.
# Document 32: The island of Korčula is believed to be the birthplace of Marco Polo and is a popular sailing destination.
# Document 10: The city of Zagreb is the capital of Croatia and offers a mix of modern and historic attractions.
# Document 73: The city of Osijek is located in the eastern part of Croatia and is known for its Baroque style.
# Document 12: The city of Knin is known for its historic fortress and beautiful scenery.
# Document 26: The island of Korcula is believed to be the birthplace of Marco Polo.
# Document 28: The city of Nin is known for its ancient salt pans and historic church.
# Document 29: The city of Vukovar is known for its role in the Croatian War of Independence.
# Document 27: The town of Motovun in Istria is famous for its film festival.
# Document 4: The city of Sibenik is home to the impressive St. James's Cathedral, a UNESCO World Heritage site.
# Document 23: The island of Mljet is home to a national park and is ideal for nature lovers.
# Document 22: The island of Rab is famous for its medieval old town and stunning beaches.
# Document 13: The island of Krk is the largest island in the Adriatic Sea.
# Document 96: The town of Samobor is famous for its traditional cream cake called 'kremsnita'.
# Document 18: The coastal town of Senj is known for its carnival and Nehaj Fortress.
# Document 16: The city of Varazdin is known for its baroque buildings and vibrant cultural scene.
# Document 11: Sailors can experience the traditional Dalmatian way of life in many coastal villages.
# Document 15: The island of Hvar is a popular destination for celebrities and high-end travelers.
# Document 81: The Brijuni Islands are a national park and a former presidential retreat.
# Document 95: The city of Šibenik is a UNESCO World Heritage site and a great stop for sailors.
# Document 56: The city of Dubrovnik, with its famous city walls, is a top destination for sailors.
# Document 75: The town of Trogir is a UNESCO World Heritage site known for its medieval architecture.
# Document 72: The city of Dubrovnik is often called the 'Pearl of the Adriatic'.
# Document 70: The Plitvice Lakes National Park is a UNESCO World Heritage site known for its stunning waterfalls and lakes.
# Document 68: The city of Trogir, with its historic architecture, is a great place to dock.
# Document 65: The city of Zadar is famous for its unique Sea Organ, an architectural sound art object.
# Document 64: The Dubrovnik Summer Festival is a major cultural event featuring theater, music, and dance performances.
# Document 63: The Peljesac Peninsula is known for its vineyards and wine production.
# Document 62: The town of Cavtat is a quieter alternative to nearby Dubrovnik.
# Document 61: The Istrian Peninsula is famous for its truffles and gourmet food.
# Document 60: The island of Mljet has a national park that is perfect for exploring by sailboat.
# Document 84: The ancient city of Pula is known for its well-preserved Roman amphitheater.
# Document 85: The city of Opatija is a historical seaside resort that welcomes sailors.
# Document 55: The island of Losinj is famous for its health tourism and clean air.
# Document 34: The city of Opatija is known for its grand villas and seaside promenade.
# Document 53: The island of Pag is famous for its cheese, which is considered a delicacy.
# Document 89: The island of Vis was a military base and was closed to tourism until the 1990s.
# Document 99: Many sailors start their Croatian adventure from the city of Zadar.
# Document 90: The city of Split is a major port and gateway to the Dalmatian islands.
# Document 92: The city of Buzet in Istria is known as the 'City of Truffles'.
# Document 44: The city of Zadar is famous for its sunsets, which sailors can enjoy from the sea.
# Document 93: The city of Karlovac is known for its parks and the rivers that flow through it.
# Document 41: Sailors can enjoy snorkeling in the clear waters of the Adriatic Sea.
# Document 39: The island of Pag is famous for its cheese and nightlife, and is a fun stop for sailors.
# Document 38: The Blue Cave on Biševo Island is a must-see for sailors.
# Document 36: The island of Brac is home to the famous Zlatni Rat beach, known for its changing shape.
# Document 35: The city of Porec is known for the Euphrasian Basilica, a UNESCO World Heritage site.
# Document 100: The coastal town of Makarska is known for its beautiful beaches and lively nightlife.
